# %% [markdown]
# # **Predicting Employee Retention**

# %% [markdown]
# ### Objective
#
# The objective of this assignment is to develop a Logistic Regression model. You will be using this model to analyse and predict binary outcomes based on the input data. This assignment aims to enhance understanding of logistic regression, including its assumptions, implementation, and evaluation, to effectively classify and interpret data.

# %% [markdown]
# ### Business Objective
#
# A mid-sized technology company wants to improve its understanding of employee retention to foster a loyal and committed workforce. While the organization has traditionally focused on addressing turnover, it recognises the value of proactively identifying employees likely to stay and understanding the factors contributing to their loyalty.
#
#
# In this assignment you’ll be building a logistic regression model to predict the likelihood of employee retention based on the data such as demographic details, job satisfaction scores, performance metrics, and tenure. The aim is to provide the HR department with actionable insights to strengthen retention strategies, create a supportive work environment, and increase the overall stability and satisfaction of the workforce.

# %% [markdown]
# ## Assignment Tasks
#
# You need to perform the following steps to complete this assignment:
# 1. Data Understanding
# 2. Data Cleaning
# 3. Train Validation Split
# 4. EDA on training data
# 5. EDA on validation data [Optional]
# 6. Feature Engineering
# 7. Model Building
# 8. Prediction and Model Evaluation

# %% [markdown]
# ## Data Dictionary
#
# The data has 24 Columns and 74610 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Employee ID</td>
#       <td>A unique identifier assigned to each employee.</td>
#     </tr>
#     <tr>
#       <td>Age</td>
#       <td>The age of the employee, ranging from 18 to 60 years.</td>
#     </tr>
#     <tr>
#       <td>Gender</td>
#       <td>The gender of the employee.</td>
#     </tr>
#     <tr>
#       <td>Years at Company</td>
#       <td>The number of years the employee has been working at the company.</td>
#     </tr>
#     <tr>
#       <td>Monthly Income</td>
#       <td>The monthly salary of the employee, in dollars.</td>
#     </tr>
#     <tr>
#       <td>Job Role</td>
#       <td>The department or role the employee works in, encoded into categories such as Finance, Healthcare, Technology, Education, and Media.</td>
#     </tr>
#     <tr>
#       <td>Work-Life Balance</td>
#       <td>The employee's perceived balance between work and personal life (Poor, Below Average, Good, Excellent).</td>
#     </tr>
#     <tr>
#       <td>Job Satisfaction</td>
#       <td>The employee's satisfaction with their job (Very Low, Low, Medium, High).</td>
#     </tr>
#     <tr>
#       <td>Performance Rating</td>
#       <td>The employee's performance rating (Low, Below Average, Average, High).</td>
#     </tr>
#     <tr>
#       <td>Number of Promotions</td>
#       <td>The total number of promotions the employee has received.</td>
#     </tr>
#      </tr>
#      <tr>
#       <td>Overtime</td>
#       <td>Number of overtime hours.</td>
#     </tr>
#     <tr>
#       <td>Distance from Home</td>
#       <td>The distance between the employee's home and workplace, in miles.</td>
#     </tr>
#     <tr>
#       <td>Education Level</td>
#       <td>The highest education level attained by the employee (High School, Associate Degree, Bachelor’s Degree, Master’s Degree, PhD).</td>
#     </tr>
#     <tr>
#       <td>Marital Status</td>
#       <td>The marital status of the employee (Divorced, Married, Single).</td>
#     </tr>
#      <tr>
#       <td>Number of Dependents</td>
#       <td>Number of dependents the employee has.</td>
#     </tr>
#     <tr>
#       <td>Job Level</td>
#       <td>The job level of the employee (Entry, Mid, Senior).</td>
#     </tr>
#     <tr>
#       <td>Company Size</td>
#       <td>The size of the company the employee works for (Small, Medium, Large).</td>
#     </tr>
#     <tr>
#       <td>Company Tenure (In Months)</td>
#       <td>The total number of years the employee has been working in the industry.</td>
#     </tr>
#     <tr>
#       <td>Remote Work</td>
#       <td>Whether the employee works remotely (Yes or No).</td>
#     </tr>
#     <tr>
#       <td>Leadership Opportunities</td>
#       <td>Whether the employee has leadership opportunities (Yes or No).</td>
#     </tr>
#     <tr>
#       <td>Innovation Opportunities</td>
#       <td>Whether the employee has opportunities for innovation (Yes or No).</td>
#     </tr>
#     <tr>
#       <td>Company Reputation</td>
#       <td>The employee's perception of the company's reputation (Very Poor, Poor, Good, Excellent).</td>
#     </tr>
#     <tr>
#       <td>Employee Recognition</td>
#       <td>The level of recognition the employee receives(Very Low, Low, Medium, High).</td>
#     </tr>
#     <tr>
#       <td>Attrition</td>
#       <td>Whether the employee has left the company.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Understanding**
#
# In this step, load the dataset and check basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ### **1.1 Load the Data**

# %%
# Load the dataset
df = pd.read_csv('Employee_data.csv')

# %%
# Check the first few entries
df.head()

#Displaying the first 5 rows of the dataset
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                     2
# 1              Poor             High                Low                     3
# 2              Good             High                Low                     0
# 3              Good             High               High                     1
# 4              Fair        Very High            Average                     0
#
#    ... Number of Dependents  Job Level Company Size  \
# 0  ...                    0        Mid       Medium
# 1  ...                    3        Mid       Medium
# 2  ...                    3        Mid       Medium
# 3  ...                    2        Mid        Small
# 4  ...                    0     Senior       Medium
#
#   Company Tenure (In Months)  Remote Work Leadership Opportunities  \
# 0                       89.0           No                       No
# 1                       21.0           No                       No
# 2                       74.0           No                       No
# 3                       50.0          Yes                       No
# 4                       68.0           No                       No
#
#   Innovation Opportunities  Company Reputation Employee Recognition Attrition
# 0                       No           Excellent               Medium    Stayed
# 1                       No                Fair                  Low    Stayed
# 2                       No                Poor                  Low    Stayed
# 3                       No                Good               Medium    Stayed
# 4                       No                Fair               Medium    Stayed
#
# [5 rows x 24 columns]

# %%
# Inspect the shape of the dataset
print("Dataset Shape:", df.shape)


# Displaying number of rows and columns in the dataset
# Out:
# Dataset Shape: (74610, 24)

# %%
# Inspect the different columns in the dataset
print("Columns in dataset:", df.columns.tolist())


#Displaying all column names in the dataset
# Out:
# Columns in dataset: ['Employee ID', 'Age', 'Gender', 'Years at Company', 'Job Role', 'Monthly Income', 'Work-Life Balance', 'Job Satisfaction', 'Performance Rating', 'Number of Promotions', 'Overtime', 'Distance from Home', 'Education Level', 'Marital Status', 'Number of Dependents', 'Job Level', 'Company Size', 'Company Tenure (In Months)', 'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities', 'Company Reputation', 'Employee Recognition', 'Attrition']

# %% [markdown]
# ### **1.2 Check the basic statistics**

# %%
# Check the summary of the dataset
df.describe(include='all')
# Out:
#          Employee ID           Age Gender  Years at Company    Job Role  \
# count   74610.000000  74610.000000  74610      74610.000000       74610
# unique           NaN           NaN      2               NaN           5
# top              NaN           NaN   Male               NaN  Technology
# freq             NaN           NaN  40898               NaN       19350
# mean    37246.028696     38.529379    NaN         15.722638         NaN
# std     21505.785344     12.082299    NaN         11.224059         NaN
# min         1.000000     18.000000    NaN          1.000000         NaN
# 25%     18624.250000     28.000000    NaN          7.000000         NaN
# 50%     37239.500000     39.000000    NaN         13.000000         NaN
# 75%     55871.750000     49.000000    NaN         23.000000         NaN
# max     74498.000000     59.000000    NaN         51.000000         NaN
#
#         Monthly Income Work-Life Balance Job Satisfaction Performance Rating  \
# count     74610.000000             74610            74610              74610
# unique             NaN                 4                4                  4
# top                NaN              Good             High            Average
# freq               NaN             28196            37306              44786
# mean       7344.931417               NaN              NaN                NaN
# std        2596.373589               NaN              NaN                NaN
# min        1226.000000               NaN              NaN                NaN
# 25%        5652.000000               NaN              NaN                NaN
# 50%        7348.500000               NaN              NaN                NaN
# 75%        8876.000000               NaN              NaN                NaN
# max       50030.000000               NaN              NaN                NaN
#
#         Number of Promotions  ... Number of Dependents  Job Level  \
# count           74610.000000  ...         74610.000000      74610
# unique                   NaN  ...                  NaN          3
# top                      NaN  ...                  NaN      Entry
# freq                     NaN  ...                  NaN      29820
# mean                0.832958  ...             1.657432        NaN
# std                 0.995326  ...             1.579862        NaN
# min                 0.000000  ...             0.000000        NaN
# 25%                 0.000000  ...             0.000000        NaN
# 50%                 1.000000  ...             1.000000        NaN
# 75%                 2.000000  ...             3.000000        NaN
# max                 4.000000  ...            15.000000        NaN
#
#        Company Size Company Tenure (In Months)  Remote Work  \
# count         74610               72197.000000        74610
# unique            3                        NaN            2
# top          Medium                        NaN           No
# freq          37281                        NaN        60390
# mean            NaN                  55.711899          NaN
# std             NaN                  25.392325          NaN
# min             NaN                   2.000000          NaN
# 25%             NaN                  36.000000          NaN
# 50%             NaN                  56.000000          NaN
# 75%             NaN                  76.000000          NaN
# max             NaN                 128.000000          NaN
#
#        Leadership Opportunities Innovation Opportunities  Company Reputation  \
# count                     74610                    74610               74610
# unique                        2                        2                   4
# top                          No                       No                Good
# freq                      70952                    62486               37241
# mean                        NaN                      NaN                 NaN
# std                         NaN                      NaN                 NaN
# min                         NaN                      NaN                 NaN
# 25%                         NaN                      NaN                 NaN
# 50%                         NaN                      NaN                 NaN
# 75%                         NaN                      NaN                 NaN
# max                         NaN                      NaN                 NaN
#
#        Employee Recognition Attrition
# count                 74610     74610
# unique                    4         2
# top                     Low    Stayed
# freq                  29654     39191
# mean                    NaN       NaN
# std                     NaN       NaN
# min                     NaN       NaN
# 25%                     NaN       NaN
# 50%                     NaN       NaN
# 75%                     NaN       NaN
# max                     NaN       NaN
#
# [11 rows x 24 columns]

# %% [markdown]
# ### **1.3 Check the data type of columns**

# %%
# Check the info to see the types of the feature variables and the null values present
df.info()


#Getting summary of the dataset including non-null counts and data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74610 entries, 0 to 74609
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee ID                 74610 non-null  int64
#  1   Age                         74610 non-null  int64
#  2   Gender                      74610 non-null  object
#  3   Years at Company            74610 non-null  int64
#  4   Job Role                    74610 non-null  object
#  5   Monthly Income              74610 non-null  int64
#  6   Work-Life Balance           74610 non-null  object
#  7   Job Satisfaction            74610 non-null  object
#  8   Performance Rating          74610 non-null  object
#  9   Number of Promotions        74610 non-null  int64
#  10  Overtime                    74610 non-null  object
#  11  Distance from Home          72698 non-null  float64
#  12  Education Level             74610 non-null  object
#  13  Marital Status              74610 non-null  object
#  14  Number of Dependents        74610 non-null  int64
#  15  Job Level                   74610 non-null  object
#  16  Company Size                74610 non-null  object
#  17  Company Tenure (In Months)  72197 non-null  float64
#  18  Remote Work                 74610 non-null  object
#  19  Leadership Opportunities    74610 non-null  object
#  20  Innovation Opportunities    74610 non-null  object
#  21  Company Reputation          74610 non-null  object
#  22  Employee Recognition        74610 non-null  object
#  23  Attrition                   74610 non-null  object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 13.7+ MB

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[15 marks]</font>

# %% [markdown]
# ### **2.1 Handle the missing values** <font color = red>[10 marks]</font>

# %% [markdown]
# 2.1.1 Check the number of missing values <font color="red">[2 Mark]</font>

# %%
# Check the number of missing values in each column
df.isnull().sum().sort_values(ascending=False)
# Out:
# Company Tenure (In Months)    2413
# Distance from Home            1912
# Employee ID                      0
# Marital Status                   0
# Employee Recognition             0
# Company Reputation               0
# Innovation Opportunities         0
# Leadership Opportunities         0
# Remote Work                      0
# Company Size                     0
# Job Level                        0
# Number of Dependents             0
# Education Level                  0
# Age                              0
# Overtime                         0
# Number of Promotions             0
# Performance Rating               0
# Job Satisfaction                 0
# Work-Life Balance                0
# Monthly Income                   0
# Job Role                         0
# Years at Company                 0
# Gender                           0
# Attrition                        0
# dtype: int64

# %% [markdown]
# 2.1.2 Check the percentage of missing values <font color="red">[2 Marks]</font>

# %%
# Check the percentage of missing values in each column
missing_percent = (df.isnull().sum() / len(df)) * 100
missing_percent[missing_percent > 0].sort_values(ascending=False)

#Counts missing values in each column and sorts them in descending order
# Out:
# Company Tenure (In Months)    3.234151
# Distance from Home            2.562659
# dtype: float64

# %% [markdown]
# 2.1.3 Handle rows with missing values <font color="red">[4 Marks]</font>

# %%
# Handle the missing value rows in the column
df.dropna(inplace=True)

#Drops all rows from the DataFrame that contain any missing values

# %% [markdown]
# 2.1.4 Check percentage of remaning data after missing values are removed <font color="red">[2 Mark]</font>

# %%
# Check the percentage of remaining data after missing values are removed

remaining_data_percentage = (len(df) / 74610) * 100
print(f"Remaining data: {remaining_data_percentage:.2f}%")

#reviewing the data after dropping missing value
# Out:
# Remaining data: 100.00%

# %% [markdown]
# ### **2.2 Identify and handle redundant values within categorical columns (if any)** <font color = red>[3 marks]</font>

# %% [markdown]
# Examine the categorical columns to determine if any value or column needs to be treated

# %%
# Write a function to display the categorical columns with their unique values and check for redundant values

#Identifing all categorical (object type) columns in the DataFrame
cat_cols = df.select_dtypes(include='object').columns

#Printing the unique values in each categorical column to check for redundant values
for col in cat_cols:
    print(f"Column: {col}")
    print(df[col].unique())
    print("-----------")
# Out:
# Column: Gender
# ['Male' 'Female']
# -----------
# Column: Job Role
# ['Education' 'Media' 'Healthcare' 'Technology' 'Finance']
# -----------
# Column: Work-Life Balance
# ['Excellent' 'Poor' 'Good' 'Fair']
# -----------
# Column: Job Satisfaction
# ['Medium' 'High' 'Very High' 'Low']
# -----------
# Column: Performance Rating
# ['Average' 'Low' 'High' 'Below Average']
# -----------
# Column: Overtime
# ['No' 'Yes']
# -----------
# Column: Education Level
# ['Associate Degree' 'Masterâ€™s Degree' 'Bachelorâ€™s Degree'
#  'High School' 'PhD']
# -----------
# Column: Marital Status
# ['Married' 'Divorced' 'Single']
# -----------
# Column: Job Level
# ['Mid' 'Senior' 'Entry']
# -----------
# Column: Company Size
# ['Medium' 'Small' 'Large']
# -----------
# Column: Remote Work
# ['No' 'Yes']
# -----------
# Column: Leadership Opportunities
# ['No' 'Yes']
# -----------
# Column: Innovation Opportunities
# ['No' 'Yes']
# -----------
# Column: Company Reputation
# ['Excellent' 'Fair' 'Poor' 'Good']
# -----------
# Column: Employee Recognition
# ['Medium' 'Low' 'High' 'Very High']
# -----------
# Column: Attrition
# ['Stayed' 'Left']
# -----------

# %%
# Check the data

 #Removing trailing whitespaces and standardizes capitalization in all categorical columns
for col in cat_cols:
    df[col] = df[col].str.strip().str.title()

#Displays updated unique values of each cleaned categorical column for verification
for col in cat_cols:
    print(f"{col}: {df[col].unique()}")
    print("-----------")
# Out:
# Gender: ['Male' 'Female']
# -----------
# Job Role: ['Education' 'Media' 'Healthcare' 'Technology' 'Finance']
# -----------
# Work-Life Balance: ['Excellent' 'Poor' 'Good' 'Fair']
# -----------
# Job Satisfaction: ['Medium' 'High' 'Very High' 'Low']
# -----------
# Performance Rating: ['Average' 'Low' 'High' 'Below Average']
# -----------
# Overtime: ['No' 'Yes']
# -----------
# Education Level: ['Associate Degree' 'Masterâ€™S Degree' 'Bachelorâ€™S Degree'
#  'High School' 'Phd']
# -----------
# Marital Status: ['Married' 'Divorced' 'Single']
# -----------
# Job Level: ['Mid' 'Senior' 'Entry']
# -----------
# Company Size: ['Medium' 'Small' 'Large']
# -----------
# Remote Work: ['No' 'Yes']
# -----------
# Leadership Opportunities: ['No' 'Yes']
# -----------
# Innovation Opportunities: ['No' 'Yes']
# -----------
# Company Reputation: ['Excellent' 'Fair' 'Poor' 'Good']
# -----------
# Employee Recognition: ['Medium' 'Low' 'High' 'Very High']
# -----------
# Attrition: ['Stayed' 'Left']
# -----------

# %% [markdown]
# ### **2.3 Drop redundant columns** <font color = red>[2 marks]</font>

# %%
df.columns
# Out:
# Index(['Employee ID', 'Age', 'Gender', 'Years at Company', 'Job Role',
#        'Monthly Income', 'Work-Life Balance', 'Job Satisfaction',
#        'Performance Rating', 'Number of Promotions', 'Overtime',
#        'Distance from Home', 'Education Level', 'Marital Status',
#        'Number of Dependents', 'Job Level', 'Company Size',
#        'Company Tenure (In Months)', 'Remote Work', 'Leadership Opportunities',
#        'Innovation Opportunities', 'Company Reputation',
#        'Employee Recognition', 'Attrition'],
#       dtype='object')

# %%
# Drop redundant columns which are not required for modelling
# Droping 'Employee ID' as it's a unique identifier and not useful for prediction
df.drop(['Employee ID'], axis=1, inplace=True)

# %%
# Check first few rows of data
df.head()
# Out:
#    Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0   31    Male                19   Education            5390
# 1   59  Female                 4       Media            5534
# 2   24  Female                10  Healthcare            8159
# 3   36  Female                 7   Education            3989
# 4   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                     2
# 1              Poor             High                Low                     3
# 2              Good             High                Low                     0
# 3              Good             High               High                     1
# 4              Fair        Very High            Average                     0
#
#   Overtime  ...  Number of Dependents Job Level Company Size  \
# 0       No  ...                     0       Mid       Medium
# 1       No  ...                     3       Mid       Medium
# 2       No  ...                     3       Mid       Medium
# 3       No  ...                     2       Mid        Small
# 4      Yes  ...                     0    Senior       Medium
#
#    Company Tenure (In Months) Remote Work Leadership Opportunities  \
# 0                        89.0          No                       No
# 1                        21.0          No                       No
# 2                        74.0          No                       No
# 3                        50.0         Yes                       No
# 4                        68.0          No                       No
#
#    Innovation Opportunities Company Reputation Employee Recognition Attrition
# 0                        No          Excellent               Medium    Stayed
# 1                        No               Fair                  Low    Stayed
# 2                        No               Poor                  Low    Stayed
# 3                        No               Good               Medium    Stayed
# 4                        No               Fair               Medium    Stayed
#
# [5 rows x 23 columns]

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import Train Test Split
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Mark]</font>

# %%
# Put all the feature variables in X

#Assigns all columns except 'Attrition' to feature variable X

X = df.drop('Attrition', axis=1)

# Put the target variable in y

#Assigns the target column 'Attrition' to variable y

y = df['Attrition']

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the data into 70% train and 30% validation data
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
#Prints the shape of training and validation feature sets

print("Training set size:", X_train.shape)
print("Validation set size:", X_val.shape)
# Out:
# Training set size: (52227, 22)
# Validation set size: (22383, 22)

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[6 marks]</font>

# %% [markdown]
# Perform univariate analysis on training data for all the numerical columns.

# %% [markdown]
# 4.1.1 Select numerical columns from training data <font color = "red">[1 Mark]</font>

# %%
# Select numerical columns
num_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
print(num_cols)
# Out:
# Index(['Age', 'Years at Company', 'Monthly Income', 'Number of Promotions',
#        'Distance from Home', 'Number of Dependents',
#        'Company Tenure (In Months)'],
#       dtype='object')

# %% [markdown]
# 4.1.2 Plot distribution of numerical columns <font color = "red">[5 Marks]</font>

# %%
# Plot all the numerical columns to understand their distribution

# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

#Plots histograms with KDE for all numerical columns in the training set to understand their distributions
plt.figure(figsize=(15, 20))
for i, col in enumerate(num_cols, 1):
    plt.subplot(6, 4, i)
    sns.histplot(X_train[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[4 Marks]</font>

# %% [markdown]
# Check the correlation among different numerical variables.

# %%
# Create correlation matrix for numerical columns
corr_matrix = X_train[num_cols].corr()

# Plot Heatmap of the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of Numerical Features")
plt.show()

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Check the distribution of target variable in training set to check class balance.

# %%
# Plot a bar chart to check class balance
sns.countplot(x=y_train)
plt.title("Class Distribution in Training Set")
plt.xlabel("Attrition")
plt.ylabel("Count")
plt.show()

#  Show value counts
print(y_train.value_counts(normalize=True) * 100)
# Out:
# Attrition
# Stayed    52.528386
# Left      47.471614
# Name: proportion, dtype: float64

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[8 Marks]</font>

# %% [markdown]
# Perform bivariate analysis on training data between all the categorical columns and target variable to  analyse how the categorical variables influence the target variable.

# %%
# Select categorical columns
cat_cols = X_train.select_dtypes(include='object').columns

# Plot distribution for each categorical column with target variable
plt.figure(figsize=(20, 25))
for i, col in enumerate(cat_cols, 1):
    plt.subplot(6, 3, i)
    sns.countplot(data=X_train.join(y_train), x=col, hue=y_train)
    plt.title(f'{col} vs Attrition')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# Perform univariate analysis on validation data for all the numerical columns.

# %% [markdown]
# 5.1.1 Select numerical columns from validation data

# %%
# Select numerical columns
val_num_cols = X_val.select_dtypes(include=['int64', 'float64']).columns
print(val_num_cols)
# Out:
# Index(['Age', 'Years at Company', 'Monthly Income', 'Number of Promotions',
#        'Distance from Home', 'Number of Dependents',
#        'Company Tenure (In Months)'],
#       dtype='object')

# %% [markdown]
# 5.1.2 Plot distribution of numerical columns

# %%
# Plot all the numerical columns to understand their distribution
plt.figure(figsize=(15, 20))
for i, col in enumerate(val_num_cols, 1):
    plt.subplot(6, 4, i)
    sns.histplot(X_val[col], kde=True)
    plt.title(f'Distribution of {col} (Validation)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
# Check the correlation among different numerical variables.

# %%
# Create correlation matrix for numerical columns
val_corr_matrix = X_val[val_num_cols].corr()

# Plot Heatmap of the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(val_corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix - Validation Set")
plt.show()

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Check the distribution of target variable in validation data to check class balance.

# %%
# Plot a bar chart to check class balance
sns.countplot(x=y_val)
plt.title("Class Distribution in Validation Set")
plt.xlabel("Attrition")
plt.ylabel("Count")
plt.show()

#how percentage
print(y_val.value_counts(normalize=True) * 100)
# Out:
# Attrition
# Stayed    52.526471
# Left      47.473529
# Name: proportion, dtype: float64

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# Perform bivariate analysis on validation data between all the categorical columns and target variable to analyse how the categorical variables influence the target variable.

# %%
# Select categorical columns from validation data
val_cat_cols = X_val.select_dtypes(include='object').columns

# Plot distribution for each categorical column with target variable
plt.figure(figsize=(20, 25))
for i, col in enumerate(val_cat_cols, 1):
    plt.subplot(6, 3, i)
    sns.countplot(data=X_val.join(y_val), x=col, hue=y_val)
    plt.title(f'{col} vs Attrition (Validation)')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **6.1 Dummy variable creation** <font color = red>[15 marks]</font>
#
#
# The next step is to deal with the categorical variables present in the data.

# %% [markdown]
# 6.1.1 Identify categorical columns where dummy variables are required <font color="red">[1 Mark]</font>

# %%
# Check the categorical columns
cat_cols = X_train.select_dtypes(include='object').columns
print(cat_cols)
# Out:
# Index(['Gender', 'Job Role', 'Work-Life Balance', 'Job Satisfaction',
#        'Performance Rating', 'Overtime', 'Education Level', 'Marital Status',
#        'Job Level', 'Company Size', 'Remote Work', 'Leadership Opportunities',
#        'Innovation Opportunities', 'Company Reputation',
#        'Employee Recognition'],
#       dtype='object')

# %% [markdown]
# 6.1.2 Create dummy variables for independent columns in training set <font color="red">[3 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for independent columns
X_train_dummies = pd.get_dummies(X_train, drop_first=True)

# Add the results to the master DataFrame
X_train_dummies.head()
# Out:
#        Age  Years at Company  Monthly Income  Number of Promotions  \
# 20940   25                 1            4207                     2
# 17495   26                13            9601                     0
# 28404   35                19            5415                     0
# 70914   21                 9            8258                     0
# 56430   53                24            6015                     1
#
#        Distance from Home  Number of Dependents  Company Tenure (In Months)  \
# 20940                 6.0                     5                        78.0
# 17495                14.0                     0                        83.0
# 28404                10.0                     3                        48.0
# 70914                50.0                     5                        16.0
# 56430                13.0                     0                        79.0
#
#        Gender_Male  Job Role_Finance  Job Role_Healthcare  ...  \
# 20940        False             False                False  ...
# 17495         True             False                 True  ...
# 28404        False             False                False  ...
# 70914         True             False                 True  ...
# 56430         True             False                False  ...
#
#        Company Size_Small  Remote Work_Yes  Leadership Opportunities_Yes  \
# 20940               False            False                          True
# 17495                True            False                          True
# 28404               False            False                         False
# 70914                True            False                         False
# 56430                True            False                          True
#
#        Innovation Opportunities_Yes  Company Reputation_Fair  \
# 20940                         False                    False
# 17495                         False                    False
# 28404                         False                    False
# 70914                         False                    False
# 56430                         False                    False
#
#        Company Reputation_Good  Company Reputation_Poor  \
# 20940                     True                    False
# 17495                     True                    False
# 28404                     True                    False
# 70914                     True                    False
# 56430                     True                    False
#
#        Employee Recognition_Low  Employee Recognition_Medium  \
# 20940                     False                        False
# 17495                     False                         True
# 28404                     False                         True
# 70914                     False                        False
# 56430                     False                        False
#
#        Employee Recognition_Very High
# 20940                           False
# 17495                           False
# 28404                           False
# 70914                           False
# 56430                           False
#
# [5 rows x 41 columns]

# %% [markdown]
# Now, drop the original categorical columns and check the DataFrame

# %%
# Drop the original categorical columns and check the DataFrame
X_train = X_train_dummies.copy()

# %% [markdown]
# 6.1.3 Create dummy variables for independent columns in validation set <font color="red">[3 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for independent columns
X_val = pd.get_dummies(X_val, drop_first=True)

# check  the results to the master DataFrame

# %% [markdown]
# Now, drop the original categorical columns and check the DataFrame

# %%
# Drop categorical columns and check the DataFrame

#Replaces the original training feature set with the dummy variable version
X_val.head()
# Out:
#        Age  Years at Company  Monthly Income  Number of Promotions  \
# 61298   45                 9           10454                     0
# 46813   44                10            3670                     0
# 37033   24                 5            6663                     0
# 41834   41                10            6042                     0
# 25905   44                16            7801                     1
#
#        Distance from Home  Number of Dependents  Company Tenure (In Months)  \
# 61298                25.0                     2                        87.0
# 46813                64.0                     0                        89.0
# 37033                18.0                     1                        65.0
# 41834                84.0                     0                        52.0
# 25905                 7.0                     5                        36.0
#
#        Gender_Male  Job Role_Finance  Job Role_Healthcare  ...  \
# 61298         True              True                False  ...
# 46813         True             False                False  ...
# 37033         True             False                False  ...
# 41834         True             False                False  ...
# 25905         True             False                 True  ...
#
#        Company Size_Small  Remote Work_Yes  Leadership Opportunities_Yes  \
# 61298                True            False                         False
# 46813               False            False                         False
# 37033               False            False                         False
# 41834                True            False                         False
# 25905                True            False                          True
#
#        Innovation Opportunities_Yes  Company Reputation_Fair  \
# 61298                         False                    False
# 46813                         False                    False
# 37033                          True                    False
# 41834                         False                    False
# 25905                         False                    False
#
#        Company Reputation_Good  Company Reputation_Poor  \
# 61298                     True                    False
# 46813                    False                    False
# 37033                    False                     True
# 41834                     True                    False
# 25905                    False                     True
#
#        Employee Recognition_Low  Employee Recognition_Medium  \
# 61298                     False                        False
# 46813                     False                         True
# 37033                     False                         True
# 41834                     False                         True
# 25905                      True                        False
#
#        Employee Recognition_Very High
# 61298                           False
# 46813                           False
# 37033                           False
# 41834                           False
# 25905                           False
#
# [5 rows x 41 columns]

# %%
#Displays the shape of the encoded training feature set
print(X_train.shape)
#Displays the shape of the unencoded validation feature set
print(X_val.shape)
# Out:
# (52227, 41)
# (22383, 41)

# %% [markdown]
# 6.1.4 Create DataFrame for dependent column in both training and validation set <font color = "red">[1 Mark]</font>

# %%
# Convert y_train and y_val to dummy variables
y_train = pd.get_dummies(y_train, drop_first=True)
y_val = pd.get_dummies(y_val, drop_first=True)

# %% [markdown]
# 6.1.5 Create dummy variables for dependent column in training set <font color="red">[3 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for dependent column
print(y_train.head())
# Out:
#            1
# 20940  False
# 17495   True
# 28404   True
# 70914  False
# 56430  False

# %% [markdown]
# 6.1.6 Create dummy variable for dependent column in validation set <font color = "red">[3 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for dependent column
print(y_val.head())
# Out:
#            1
# 61298   True
# 46813  False
# 37033   True
# 41834  False
# 25905  False

# %% [markdown]
# 6.1.7 Drop redundant columns <font color="red">[1 Mark]</font>

# %%
# Drop redundant columns from both train and validation
y_train.columns = ['Attrition']
y_val.columns = ['Attrition']

# %% [markdown]
# ### **6.2 Feature scaling** <font color = red>[5 marks]</font>
#
# Apply feature scaling to the numeric columns to bring them to a common range and ensure consistent scaling.

# %% [markdown]
# 6.2.1 Import required libraries <font color="red">[1 Mark]</font>

# %%
# Import the necessary scaling tool from scikit-learn
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# 6.2.2 Scale the numerical features <font color="red">[4 Marks]</font>

# %%
# Scale the numeric features present in the training set
X_train_scaled = scaler.fit_transform(X_train)

# Scale the numerical features present in the validation set
X_val_scaled = scaler.transform(X_val)

# Convert scaled arrays back to DataFrame
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_val_scaled = pd.DataFrame(X_val_scaled, columns=X_val.columns, index=X_val.index)
# Out:
# (52227, 41)
# (22383, 41)

# %%
#check result
print(X_train_scaled.shape)
print(X_val_scaled.shape)

print(X_train_scaled.columns.tolist())
# Out:
# (52227, 41)
# (22383, 41)
# ['Age', 'Years at Company', 'Monthly Income', 'Number of Promotions', 'Distance from Home', 'Number of Dependents', 'Company Tenure (In Months)', 'Gender_Male', 'Job Role_Finance', 'Job Role_Healthcare', 'Job Role_Media', 'Job Role_Technology', 'Work-Life Balance_Fair', 'Work-Life Balance_Good', 'Work-Life Balance_Poor', 'Job Satisfaction_Low', 'Job Satisfaction_Medium', 'Job Satisfaction_Very High', 'Performance Rating_Below Average', 'Performance Rating_High', 'Performance Rating_Low', 'Overtime_Yes', 'Education Level_Bachelorâ€™S Degree', 'Education Level_High School', 'Education Level_Masterâ€™S Degree', 'Education Level_Phd', 'Marital Status_Married', 'Marital Status_Single', 'Job Level_Mid', 'Job Level_Senior', 'Company Size_Medium', 'Company Size_Small', 'Remote Work_Yes', 'Leadership Opportunities_Yes', 'Innovation Opportunities_Yes', 'Company Reputation_Fair', 'Company Reputation_Good', 'Company Reputation_Poor', 'Employee Recognition_Low', 'Employee Recognition_Medium', 'Employee Recognition_Very High']

# %% [markdown]
# ## **7. Model Building** <font color = red>[40 marks]</font>

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[5 marks]</font>
#
# As there are a lot of variables present in the data, Recursive Feature Elimination (RFE) will be used to select the most influential features for building the model.

# %% [markdown]
# 7.1.1 Import required libraries <font color="red">[1 Mark]</font>

# %%
# Import 'LogisticRegression' and create a LogisticRegression object
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter=1000)

# %% [markdown]
# 7.1.2 Import RFE  and select 15 variables <font color="red">[3 Mark]</font>

# %%
# Import RFE and select 15 variables
from sklearn.feature_selection import RFE

# Apply RFE with 15 features
rfe = RFE(logreg, n_features_to_select=15)
rfe.fit(X_train_scaled, y_train)
# Out:
# RFE(estimator=LogisticRegression(max_iter=1000), n_features_to_select=15)

# %%
# Display the features selected by RFE
selected_features = X_train_scaled.columns[rfe.support_]
print("Selected Features:\n", selected_features)
# Out:
# Selected Features:
#  Index(['Years at Company', 'Number of Promotions', 'Distance from Home',
#        'Number of Dependents', 'Gender_Male', 'Work-Life Balance_Fair',
#        'Work-Life Balance_Poor', 'Job Satisfaction_Very High',
#        'Education Level_Phd', 'Marital Status_Single', 'Job Level_Mid',
#        'Job Level_Senior', 'Remote Work_Yes', 'Company Reputation_Fair',
#        'Company Reputation_Poor'],
#       dtype='object')

# %% [markdown]
# 7.1.3 Store the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFE into variable 'col'
col = selected_features.tolist()

# %% [markdown]
# ### **7.2 Building Logistic Regression Model** <font color = red>[20 marks]</font>
#
# Now that you have selected the variables through RFE, use these features to build a logistic regression model with statsmodels. This will allow you to assess the statistical aspects, such as p-values and VIFs, which are important for checking multicollinearity and ensuring that the predictors are not highly correlated with each other, as this could distort the model's coefficients.

# %% [markdown]
# 7.2.1 Select relevant columns on training set <font color="red">[1 Mark]</font>

# %%
# Select only the columns selected by RFE
X_train_sm = X_train_scaled[col]
X_val_sm = X_val_scaled[col]

# %%
# View the training data
X_train_sm.head()
# Out:
#        Years at Company  Number of Promotions  Distance from Home  \
# 20940         -1.308255              1.169352           -1.566205
# 17495         -0.240890             -0.836255           -1.281911
# 28404          0.292793             -0.836255           -1.424058
# 70914         -0.596678             -0.836255           -0.002589
# 56430          0.737529              0.166548           -1.317448
#
#        Number of Dependents  Gender_Male  Work-Life Balance_Fair  \
# 20940              2.116214    -1.097543               -0.658742
# 17495             -1.047331     0.911126                1.518045
# 28404              0.850796    -1.097543               -0.658742
# 70914              2.116214     0.911126               -0.658742
# 56430             -1.047331     0.911126                1.518045
#
#        Work-Life Balance_Poor  Job Satisfaction_Very High  \
# 20940               -0.404378                   -0.503934
# 17495               -0.404378                   -0.503934
# 28404               -0.404378                   -0.503934
# 70914               -0.404378                   -0.503934
# 56430               -0.404378                   -0.503934
#
#        Education Level_Phd  Marital Status_Single  Job Level_Mid  \
# 20940            -0.232252               1.366014      -0.815233
# 17495             4.305661              -0.732057      -0.815233
# 28404            -0.232252               1.366014       1.226643
# 70914            -0.232252              -0.732057       1.226643
# 56430            -0.232252              -0.732057      -0.815233
#
#        Job Level_Senior  Remote Work_Yes  Company Reputation_Fair  \
# 20940          1.986860        -0.485222                -0.496815
# 17495         -0.503307        -0.485222                -0.496815
# 28404         -0.503307        -0.485222                -0.496815
# 70914         -0.503307        -0.485222                -0.496815
# 56430         -0.503307        -0.485222                -0.496815
#
#        Company Reputation_Poor
# 20940                -0.505577
# 17495                -0.505577
# 28404                -0.505577
# 70914                -0.505577
# 56430                -0.505577

# %% [markdown]
# 7.2.2 Add constant to training set <font color = "red">[1 Mark]</font>

# %%
# Import statsmodels and add constant to training set
import statsmodels.api as sm

X_train_sm = sm.add_constant(X_train_sm)

# %% [markdown]
# 7.2.3 Fit logistic regression model <font color="red">[3 Marks]</font>

# %%
# Fit a logistic regression model on X_train after adding a constant and output the summary
logit_model = sm.Logit(y_train, X_train_sm)
result = logit_model.fit()

# Display the model summary
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.492654
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Attrition   No. Observations:                52227
# Model:                          Logit   Df Residuals:                    52211
# Method:                           MLE   Df Model:                           15
# Date:                Mon, 28 Jul 2025   Pseudo R-squ.:                  0.2879
# Time:                        19:51:27   Log-Likelihood:                -25730.
# converged:                       True   LL-Null:                       -36134.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -0.1838      0.011    -16.661      0.000      -0.205      -0.162
# Years at Company              -0.1975      0.011    -18.085      0.000      -0.219      -0.176
# Number of Promotions          -0.2617      0.011    -23.779      0.000      -0.283      -0.240
# Distance from Home             0.2707      0.011     24.690      0.000       0.249       0.292
# Number of Dependents          -0.2283      0.011    -20.674      0.000      -0.250      -0.207
# Gender_Male                   -0.2968      0.011    -27.139      0.000      -0.318      -0.275
# Work-Life Balance_Fair         0.5131      0.011     44.666      0.000       0.491       0.536
# Work-Life Balance_Poor         0.4493      0.012     39.017      0.000       0.427       0.472
# Job Satisfaction_Very High     0.1775      0.011     16.343      0.000       0.156       0.199
# Education Level_Phd           -0.3546      0.012    -29.156      0.000      -0.378      -0.331
# Marital Status_Single          0.8343      0.012     71.363      0.000       0.811       0.857
# Job Level_Mid                 -0.4860      0.012    -41.430      0.000      -0.509      -0.463
# Job Level_Senior              -1.0490      0.014    -75.742      0.000      -1.076      -1.022
# Remote Work_Yes               -0.6824      0.012    -56.398      0.000      -0.706      -0.659
# Company Reputation_Fair        0.1875      0.011     16.724      0.000       0.166       0.209
# Company Reputation_Poor        0.3088      0.011     27.238      0.000       0.287       0.331
# ==============================================================================================
# """

# %% [markdown]
# **Model Interpretation**
#
# The output summary table  will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e,  an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# 7.2.4 Evaluate VIF of features <font color="red">[3 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF DataFrame for all the variables present
vif = pd.DataFrame()
vif["Feature"] = X_train_sm.columns
vif["VIF"] = [variance_inflation_factor(X_train_sm.values, i) for i in range(X_train_sm.shape[1])]
vif.sort_values(by="VIF", ascending=False)
# Out:
#                        Feature       VIF
# 11               Job Level_Mid  1.202784
# 12            Job Level_Senior  1.202615
# 7       Work-Life Balance_Poor  1.076691
# 6       Work-Life Balance_Fair  1.076607
# 14     Company Reputation_Fair  1.067543
# 15     Company Reputation_Poor  1.067465
# 3           Distance from Home  1.000422
# 9          Education Level_Phd  1.000389
# 4         Number of Dependents  1.000355
# 8   Job Satisfaction_Very High  1.000339
# 5                  Gender_Male  1.000296
# 10       Marital Status_Single  1.000252
# 1             Years at Company  1.000179
# 13             Remote Work_Yes  1.000173
# 2         Number of Promotions  1.000149
# 0                        const  1.000000

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges.  If you observe high p-values or VIFs, create new cells to drop the features and retrain the model.

# %% [markdown]
# 7.2.5 Make predictions on training set <font color = "red">[2 Marks]</font>

# %%
# Predict the probabilities on the training set
y_train_pred = result.predict(X_train_sm)
y_train_pred[:10]  # Check first 10 probabilities
# Out:
# 20940    0.141142
# 17495    0.285082
# 28404    0.586570
# 70914    0.151193
# 56430    0.555913
# 64807    0.351792
# 28273    0.786861
# 16673    0.459897
# 61687    0.130775
# 64555    0.762897
# dtype: float64

# %% [markdown]
# 7.2.6 Format the prediction output <font color="red">[1 Mark]</font>

# %%
# Reshape it into an array
y_train_pred = np.array(y_train_pred)
y_train_pred[:10]  # Optional: Check first 10 values
# Out:
# array([0.14114222, 0.28508183, 0.58657007, 0.151193  , 0.55591312,
#        0.35179162, 0.78686133, 0.45989702, 0.13077538, 0.7628974 ])

# %% [markdown]
# 7.2.7 Create a DataFrame with the actual stayed flag and the predicted probabilities <font color="red">[1 Mark]</font>

# %%
# Make sure both y_train and y_train_pred are 1D arrays
y_train_1d = y_train.values.ravel() if hasattr(y_train, 'values') else y_train.ravel()
y_train_pred_1d = y_train_pred.ravel()

# Now create the DataFrame
y_train_df = pd.DataFrame({
    'Attrition': y_train_1d,
    'Attrition_Prob': y_train_pred_1d
})

y_train_df.head()
# Out:
#    Attrition  Attrition_Prob
# 0      False        0.141142
# 1       True        0.285082
# 2       True        0.586570
# 3      False        0.151193
# 4      False        0.555913

# %% [markdown]
# 7.2.8 Create a new column 'Predicted' with 1 if predicted probabilities are greater than 0.5 else 0 <font color = "red">[1 Mark]</font>

# %%
# Create a new column 'Predicted' with 1 if predicted probabilities are greater than 0.5 else 0
y_train_df['Attrition_Pred'] = y_train_df['Attrition_Prob'].apply(lambda x: 1 if x >= 0.5 else 0)

# Preview
y_train_df.head()
# Out:
#    Attrition  Attrition_Prob  Attrition_Pred
# 0      False        0.141142               0
# 1       True        0.285082               0
# 2       True        0.586570               1
# 3      False        0.151193               0
# 4      False        0.555913               1

# %% [markdown]
# **Evaluation of performance of Model**
#
# Evaluate the performance of the model based on the predictions made on the training set.

# %% [markdown]
# 7.2.9 Check the accuracy of the model based on the predictions made on the training set <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation
from sklearn import metrics

# Check the overall accuracy
metrics.accuracy_score(y_train_df['Attrition'], y_train_df['Attrition_Pred'])
# Out:
# 0.7465104256419094

# %% [markdown]
# 7.2.10 Create a confusion matrix based on the predictions made on the training set <font color="red">[1 mark]</font>

# %%
# Importconfusion  metrics
from sklearn.metrics import confusion_matrix

# Create confusion matrix

confusion = confusion_matrix(y_train_df['Attrition'], y_train_df['Attrition_Pred'])
print(confusion)
# Out:
# [[20904  6530]
#  [ 6709 18084]]

# %% [markdown]
# 7.2.11 Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN, FP, FN, TP = confusion.ravel()

print(f"True Positives: {TP}")
print(f"True Negatives: {TN}")
print(f"False Positives: {FP}")
print(f"False Negatives: {FN}")
# Out:
# True Positives: 18084
# True Negatives: 20904
# False Positives: 6530
# False Negatives: 6709

# %% [markdown]
# 7.2.12 Calculate sensitivity and specificity of model  <font color="red">[2 Marks]</font>

# %%
# Calculate sensitivity
sensitivity = TP / (TP + FN)

# %%
# Calculate specificity
specificity = TN / (TN + FP)

print(f"Sensitivity: {sensitivity}")
print(f"Specificity: {specificity}")
# Out:
# Sensitivity: 0.7293994272576937
# Specificity: 0.761974192607713

# %% [markdown]
# 7.2.13 Calculate precision and recall of model <font color="red">[2 Marks]</font>

# %%
# Calculate precision
precision = TP / (TP + FP)

# %%
# Calculate recall
recall = TP / (TP + FN)

print(f"Precision: {precision}")
print(f"Recall: {recall}")
# Out:
# Precision: 0.7347038270902738
# Recall: 0.7293994272576937

# %% [markdown]
# ### **7.3 Find the optimal cutoff** <font color = red>[15 marks]</font>
#
# Find the optimal cutoff to improve model performance. While a default threshold of 0.5 was used for initial evaluation, optimising this threshold can enhance the model's performance.
#
# First, plot the ROC curve and check AUC.

# %% [markdown]
# 7.3.1 Plot ROC curve <font color="red">[3 Marks]</font>

# %%
# Define ROC function
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

def draw_roc(actual, probs):
    fpr, tpr, thresholds = roc_curve(actual, probs)
    auc_score = roc_auc_score(actual, probs)
    plt.figure(figsize=(8,6))
    plt.plot(fpr, tpr, label='ROC Curve (area = %0.2f)' % auc_score)
    plt.plot([0, 1], [0, 1], 'k--')  # diagonal
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc='lower right')
    plt.show()

# %%
# Call the ROC function
draw_roc(y_train_df.Attrition, y_train_df.Attrition_Prob)

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# Check sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# 7.3.2 Predict on training set at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
# Predict on training data by creating columns with different probability cutoffs to explore the impact of cutoff on model performance
# Create a list of cutoffs from 0.0 to 1.0 with step 0.01
cutoffs = np.arange(0.0, 1.01, 0.01)
cutoff_df = pd.DataFrame(columns=['probability', 'accuracy', 'sensitivity', 'specificity'])

for cutoff in cutoffs:
    y_train_df['Predicted'] = y_train_df['Attrition_Prob'].map(lambda x: 1 if x > cutoff else 0)
    cm = metrics.confusion_matrix(y_train_df.Attrition, y_train_df.Predicted)
    tn, fp, fn, tp = cm.ravel()
    total = tn + fp + fn + tp
    acc = (tp + tn) / total
    sens = tp / (tp + fn)
    spec = tn / (tn + fp)
    cutoff_df.loc[len(cutoff_df)] = [cutoff, acc, sens, spec]

# %% [markdown]
# 7.3.3 Plot for accuracy, sensitivity, specificity at different probability cutoffs <font color="red">[2 Marks]</font>

# %%
# Create a DataFrame to see the values of accuracy, sensitivity, and specificity at different values of probability cutoffs
# Plot the trade-off
plt.figure(figsize=(10,6))
plt.plot(cutoff_df['probability'], cutoff_df['accuracy'], label='Accuracy')
plt.plot(cutoff_df['probability'], cutoff_df['sensitivity'], label='Sensitivity')
plt.plot(cutoff_df['probability'], cutoff_df['specificity'], label='Specificity')
plt.xlabel('Probability Cutoff')
plt.ylabel('Score')
plt.title('Cutoff vs Accuracy/Sensitivity/Specificity')
plt.legend()
plt.grid()
plt.show()

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs
plt.figure(figsize=(10,6))

plt.plot(cutoff_df['probability'], cutoff_df['accuracy'], label='Accuracy', color='blue')
plt.plot(cutoff_df['probability'], cutoff_df['sensitivity'], label='Sensitivity', color='green')
plt.plot(cutoff_df['probability'], cutoff_df['specificity'], label='Specificity', color='red')

plt.xlabel('Probability Cutoff')
plt.ylabel('Score')
plt.title('Cutoff vs Accuracy, Sensitivity, Specificity')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 7.3.4 Create a column for final prediction based on the optimal cutoff <font color="red">[2 Marks]</font>

# %%
# Create a column for final prediction based on the optimal cutoff
y_train_df['Attrition_Final_Pred'] = y_train_df['Attrition_Prob'].apply(lambda x: 1 if x > optimal_cutoff else 0)
y_train_df.head()
# Out:
#    Attrition  Attrition_Prob  Attrition_Pred  Predicted  Attrition_Final_Pred
# 0      False        0.141142               0          0                     0
# 1       True        0.285082               0          0                     0
# 2       True        0.586570               1          0                     1
# 3      False        0.151193               0          0                     0
# 4      False        0.555913               1          0                     1

# %% [markdown]
# 7.3.5 Calculate model's accuracy <font color="red">[1Mark]</font>

# %%
# Calculate the accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_train_df['Attrition'], y_train_df['Attrition_Final_Pred'])
# Out:
# 0.7465104256419094

# %% [markdown]
# 7.3.6 Create confusion matrix <font color="red">[1Mark]</font>

# %%
# Create the confusion matrix once again
from sklearn.metrics import confusion_matrix
confusion_final = confusion_matrix(y_train_df['Attrition'], y_train_df['Attrition_Final_Pred'])
print(confusion_final)
# Out:
# [[20904  6530]
#  [ 6709 18084]]

# %% [markdown]
# 7.3.7 Create variables for true positive, true negative, false positive and false negative <font color="red">[1Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
TN, FP, FN, TP = confusion_final.ravel()
print("True Positives:", TP)
print("True Negatives:", TN)
print("False Positives:", FP)
print("False Negatives:", FN)
# Out:
# True Positives: 18084
# True Negatives: 20904
# False Positives: 6530
# False Negatives: 6709

# %% [markdown]
# 7.3.8 Calculate sensitivity and specificity of the model <font color="red">[1Mark]</font>

# %%
# Calculate Sensitivity
sensitivity_final = TP / (TP + FN)

# %%
# Calculate Specificity
specificity_final = TN / (TN + FP)

print("Sensitivity:", sensitivity_final)
print("Specificity:", specificity_final)
# Out:
# Sensitivity: 0.7293994272576937
# Specificity: 0.761974192607713

# %% [markdown]
# 7.3.9 Calculate precision and recall of the model <font color="red">[1Mark]</font>

# %%
from sklearn.metrics import precision_score, recall_score

# Calculate Precision
precision_final = precision_score(y_train_df['Attrition'], y_train_df['Attrition_Final_Pred'])

# %%
# Calculate Recall
recall_final = recall_score(y_train_df['Attrition'], y_train_df['Attrition_Final_Pred'])

print("Precision:", precision_final)
print("Recall:", recall_final)
# Out:
# Precision: 0.7347038270902738
# Recall: 0.7293994272576937

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on the precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# %%
# Check actual and predicted values from initial model
y_true = y_train_df['Attrition']
y_scores = y_train_df['Attrition_Prob']  # predicted probabilities from logistic regression

# %% [markdown]
# 7.3.10 Plot precision-recall curve <font color="red">[2 Marks]</font>

# %%
# Plot precision-recall curve
precision, recall, thresholds = precision_recall_curve(y_true, y_scores)

plt.figure(figsize=(8,6))
plt.plot(thresholds, precision[:-1], label="Precision", color="blue")
plt.plot(thresholds, recall[:-1], label="Recall", color="green")
plt.xlabel("Threshold")
plt.ylabel("Precision / Recall")
plt.title("Precision-Recall Tradeoff Curve")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[30 marks]</font>
#
# Use the model from the previous step to make predictions on the validation set with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation set** <font color = red>[15 marks]</font>

# %% [markdown]
# 8.1.1 Select relevant features for validation set <font color="red">[2 Marks]</font>

# %%
# Select the relevant features for validation set
X_validation = X_val_sm.copy()

# %% [markdown]
# 8.1.2 Add constant to X_validation <font color="red">[2 Marks]</font>

# %%
# Add constant to X_validation
X_validation = X_val_sm.copy()

# %% [markdown]
# 8.1.3 Make predictions over validation set <font color="red">[3 Marks]</font>

# %%
# Step 1: Match columns
X_validation = X_val_sm[X_train_sm.drop('const', axis=1).columns]

# Step 2: Add constant
X_validation = sm.add_constant(X_validation, has_constant='add')

# Step 3: Use correct fitted model object
y_validation_pred = result.predict(X_validation)

# Optional: View
y_validation_pred[:5]
# Out:
# 61298    0.368203
# 46813    0.291963
# 37033    0.873566
# 41834    0.604307
# 25905    0.085159
# dtype: float64

# %% [markdown]
# 8.1.4 Create DataFrame with actual values and predicted values for validation set <font color="red">[5 Marks]</font>

# %%
# Convert 'y_validation_pred' to a DataFrame 'predicted_probability'
predicted_probability = pd.DataFrame(y_validation_pred, columns=['predicted_probability'])


# Convert 'y_validation' to DataFrame 'actual'
actual = pd.DataFrame(y_val.values, columns=['actual'])

# Remove index from both DataFrames 'actual' and 'predicted_probability' to append them side by side
predicted_probability.reset_index(drop=True, inplace=True)
actual.reset_index(drop=True, inplace=True)

# Append both side-by-side
validation_df = pd.concat([actual, predicted_probability], axis=1)

# Check the combined DataFrame
validation_df.head()
# Out:
#    actual  predicted_probability
# 0    True               0.368203
# 1   False               0.291963
# 2    True               0.873566
# 3   False               0.604307
# 4   False               0.085159

# %% [markdown]
# 8.1.5 Predict final prediction based on the cutoff value <font color="red">[3 Marks]</font>

# %%
# Make predictions on the validation set using the optimal cutoff and store it in a column 'final_prediction'
cutoff = 0.3  # <-- Replace this with your actual optimal cutoff value if different
validation_df['final_prediction'] = validation_df['predicted_probability'].apply(lambda x: 1 if x > cutoff else 0)


# Check the DataFrame
validation_df.head()
# Out:
#    actual  predicted_probability  final_prediction
# 0    True               0.368203                 1
# 1   False               0.291963                 0
# 2    True               0.873566                 1
# 3   False               0.604307                 1
# 4   False               0.085159                 0

# %% [markdown]
# ### **8.2 Calculate accuracy of the model** <font color = red>[2 marks]</font>

# %%
# Calculate the overall accuracy
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(validation_df['actual'], validation_df['final_prediction'])
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7177322074788902

# %% [markdown]
# ### **8.3 Create confusion matrix and create variables for true positive, true negative, false positive and false negative** <font color = red>[5 marks]</font>

# %%
# Create confusion matrix
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(validation_df['actual'], validation_df['final_prediction'])
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Confusion Matrix:
#  [[6581 5176]
#  [1142 9484]]

# %%
# Create variables for true positive, true negative, false positive and false negative
TN, FP, FN, TP = conf_matrix.ravel()
print("True Positives:", TP)
print("True Negatives:", TN)
print("False Positives:", FP)
print("False Negatives:", FN)
# Out:
# True Positives: 9484
# True Negatives: 6581
# False Positives: 5176
# False Negatives: 1142

# %% [markdown]
# ### **8.4 Calculate sensitivity and specificity** <font color = red>[4 marks]</font>

# %%
# Calculate sensitivity
sensitivity = TP / (TP + FN)
print("Sensitivity:", sensitivity)
# Out:
# Sensitivity: 0.8925277620929795

# %%
# Calculate specificity
specificity = TN / (TN + FP)
print("Specificity:", specificity)
# Out:
# Specificity: 0.5597516373224461

# %% [markdown]
# ### **8.5 Calculate precision and recall** <font color = red>[4 marks]</font>

# %%
# Calculate precision
from sklearn.metrics import precision_score, recall_score
precision = precision_score(validation_df['actual'], validation_df['final_prediction'])
print("Precision:", precision)
# Out:
# Precision: 0.6469304229195089

# %%
# Calculate recall
recall = recall_score(validation_df['actual'], validation_df['final_prediction'])
print("Recall:", recall)
# Out:
# Recall: 0.8925277620929795

# %% [markdown]
# ## Conclusion

# %%
The purpose of this model was to predict employee attrition — identifying which employees are likely to leave the company. 
We used logistic regression to train and test the model.

# %%
The optimal cutoff was found to be 0.50, which balances both sensitivity and specificity, achieving approximately 71% accuracy on the training data

# %%
The overall accuracy of the model is 71%, showing it works reasonably well.

# %%
The recall (sensitivity) is 89.25%, which is very good.

# %%
The precision is 64.9%, meaning that among the employees predicted to leave, around 65% actually do

# %%
The specificity is 55.9%, indicating that the model is less accurate in identifying employees who will stay.
